# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
df = pd.read_csv("df.csv")

# %%
df.describe()
# Out:
#        Employee ID          Age    DailyRate  DistanceFromHome   Education  \
# count    147.000000  147.000000   147.000000        147.000000  147.000000
# mean     679.741497   36.585034   812.659864          8.435374    2.884354
# std      408.202241    9.006728   402.256929          7.670499    0.975852
# min       12.000000   18.000000   103.000000          1.000000    1.000000
# 25%      335.000000   30.000000   472.500000          2.000000    2.000000
# 50%      606.000000   35.000000   829.000000          7.000000    3.000000
# 75%     1051.000000   43.000000  1141.000000         11.000000    4.000000
# max     1470.000000   59.000000  1495.000000         29.000000    5.000000
#
#        JobSatisfaction  MonthlyIncome  PercentSalaryHike  TotalWorkingYears  \
# count       147.000000     147.000000         147.000000         147.000000
# mean          2.734694    6582.367347          15.136054          11.591837
# std           1.074783    4527.912943           3.724483           8.088344
# min           1.000000    1009.000000          11.000000           0.000000
# 25%           2.000000    3200.500000          12.000000           6.000000
# 50%           3.000000    5296.000000          14.000000          10.000000
# 75%           4.000000    8443.000000          18.000000          15.000000
# max           4.000000   19926.000000          25.000000          40.000000
#
#        TrainingTimesLastYear  YearsAtCompany  YearsSinceLastPromotion  \
# count             147.000000      147.000000               147.000000
# mean                2.850340        6.544218                 2.122449
# std                 1.439909        5.994554                 2.976847
# min                 0.000000        0.000000                 0.000000
# 25%                 2.000000        2.000000                 0.000000
# 50%                 3.000000        5.000000                 1.000000
# 75%                 3.000000        9.000000                 3.000000
# max                 6.000000       40.000000                15.000000
#
#        YearsWithCurrManager
# count            147.000000
# mean               3.972789
# std                3.293717
# min                0.000000
# 25%                2.000000
# 50%                3.000000
# 75%                7.000000
# max               15.000000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 147 entries, 0 to 146
# Data columns (total 18 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Employee ID              147 non-null    int64
#  1   Age                      147 non-null    int64
#  2   Attrition                147 non-null    object
#  3   DailyRate                147 non-null    int64
#  4   Department               147 non-null    object
#  5   DistanceFromHome         147 non-null    int64
#  6   Education                147 non-null    int64
#  7   Gender                   147 non-null    object
#  8   JobSatisfaction          147 non-null    int64
#  9   MaritalStatus            147 non-null    object
#  10  MonthlyIncome            147 non-null    int64
#  11  PercentSalaryHike        147 non-null    int64
#  12  TotalWorkingYears        147 non-null    int64
#  13  TrainingTimesLastYear    147 non-null    int64
#  14  YearsAtCompany           147 non-null    int64
#  15  YearsSinceLastPromotion  147 non-null    int64
#  16  YearsWithCurrManager     147 non-null    int64
#  17  Random sample            147 non-null    object
# dtypes: int64(13), object(5)
# memory usage: 20.8+ KB

# %%
df.head()
# Out:
#    Employee ID   Age Attrition  DailyRate              Department  \
# 0            12   29        No        153  Research & Development
# 1            14   34        No       1346  Research & Development
# 2            15   28       Yes        103  Research & Development
# 3            24   21        No        391  Research & Development
# 4            30   46        No        705                   Sales
#
#    DistanceFromHome  Education  Gender  JobSatisfaction MaritalStatus  \
# 0                15          2  Female                3        Single
# 1                19          2    Male                4      Divorced
# 2                24          3    Male                3        Single
# 3                15          2    Male                4        Single
# 4                 2          4  Female                1        Single
#
#    MonthlyIncome  PercentSalaryHike  TotalWorkingYears  TrainingTimesLastYear  \
# 0           4193                 12                 10                      3
# 1           2661                 11                  3                      2
# 2           2028                 14                  6                      4
# 3           1232                 14                  0                      6
# 4          18947                 12                 22                      2
#
#    YearsAtCompany  YearsSinceLastPromotion  YearsWithCurrManager  \
# 0               9                        0                     8
# 1               2                        1                     2
# 2               4                        0                     3
# 3               0                        0                     0
# 4               2                        2                     1
#
#   Random sample
# 0              B
# 1              B
# 2              B
# 3              B
# 4              B

# %%
plt.figure(figsize = (12,12))
sns.scatterplot(x = 'MonthlyIncome', y = 'TotalWorkingYears', data = df)
# Out:
# <AxesSubplot:xlabel='MonthlyIncome', ylabel='TotalWorkingYears'>

# %%
df.corr()
# Out:
#                          Employee ID        Age  DailyRate  DistanceFromHome  \
# Employee ID                  1.000000 -0.082838  -0.001994         -0.048089
# Age                         -0.082838  1.000000   0.046701          0.007590
# DailyRate                   -0.001994  0.046701   1.000000          0.047275
# DistanceFromHome            -0.048089  0.007590   0.047275          1.000000
# Education                    0.056116  0.213482  -0.159930          0.073570
# JobSatisfaction              0.029755  0.075578  -0.068697         -0.051527
# MonthlyIncome               -0.048132  0.587004   0.111903         -0.071394
# PercentSalaryHike           -0.013988 -0.031791  -0.003018         -0.167994
# TotalWorkingYears           -0.078394  0.771914   0.043148          0.034789
# TrainingTimesLastYear       -0.063890 -0.188084  -0.022722         -0.028168
# YearsAtCompany              -0.089678  0.233954  -0.042183          0.143175
# YearsSinceLastPromotion     -0.001800  0.239231   0.032913          0.132332
# YearsWithCurrManager        -0.121683  0.047641  -0.051657          0.071230
#
#                          Education  JobSatisfaction  MonthlyIncome  \
# Employee ID               0.056116         0.029755      -0.048132
# Age                       0.213482         0.075578       0.587004
# DailyRate                -0.159930        -0.068697       0.111903
# DistanceFromHome          0.073570        -0.051527      -0.071394
# Education                 1.000000        -0.107819       0.227138
# JobSatisfaction          -0.107819         1.000000      -0.072860
# MonthlyIncome             0.227138        -0.072860       1.000000
# PercentSalaryHike        -0.057830         0.087787      -0.132068
# TotalWorkingYears         0.190094        -0.028300       0.763634
# TrainingTimesLastYear    -0.056272         0.058258      -0.165434
# YearsAtCompany            0.029566        -0.006140       0.287306
# YearsSinceLastPromotion   0.165238        -0.030451       0.267725
# YearsWithCurrManager     -0.015903        -0.141360       0.168682
#
#                          PercentSalaryHike  TotalWorkingYears  \
# Employee ID                      -0.013988          -0.078394
# Age                              -0.031791           0.771914
# DailyRate                        -0.003018           0.043148
# DistanceFromHome                 -0.167994           0.034789
# Education                        -0.057830           0.190094
# JobSatisfaction                   0.087787          -0.028300
# MonthlyIncome                    -0.132068           0.763634
# PercentSalaryHike                 1.000000          -0.114554
# TotalWorkingYears                -0.114554           1.000000
# TrainingTimesLastYear             0.008931          -0.207588
# YearsAtCompany                   -0.118381           0.525311
# YearsSinceLastPromotion          -0.094178           0.377586
# YearsWithCurrManager             -0.129788           0.331239
#
#                          TrainingTimesLastYear  YearsAtCompany  \
# Employee ID                          -0.063890       -0.089678
# Age                                  -0.188084        0.233954
# DailyRate                            -0.022722       -0.042183
# DistanceFromHome                     -0.028168        0.143175
# Education                            -0.056272        0.029566
# JobSatisfaction                       0.058258       -0.006140
# MonthlyIncome                        -0.165434        0.287306
# PercentSalaryHike                     0.008931       -0.118381
# TotalWorkingYears                    -0.207588        0.525311
# TrainingTimesLastYear                 1.000000       -0.113494
# YearsAtCompany                       -0.113494        1.000000
# YearsSinceLastPromotion              -0.054819        0.630320
# YearsWithCurrManager                 -0.078851        0.727857
#
#                          YearsSinceLastPromotion  YearsWithCurrManager
# Employee ID                            -0.001800             -0.121683
# Age                                     0.239231              0.047641
# DailyRate                               0.032913             -0.051657
# DistanceFromHome                        0.132332              0.071230
# Education                               0.165238             -0.015903
# JobSatisfaction                        -0.030451             -0.141360
# MonthlyIncome                           0.267725              0.168682
# PercentSalaryHike                      -0.094178             -0.129788
# TotalWorkingYears                       0.377586              0.331239
# TrainingTimesLastYear                  -0.054819             -0.078851
# YearsAtCompany                          0.630320              0.727857
# YearsSinceLastPromotion                 1.000000              0.515182
# YearsWithCurrManager                    0.515182              1.000000

# %%
plt.figure(figsize = (15,8))
sns.heatmap(df.corr(), annot = True)
# Out:
# <AxesSubplot:>

# %%
from sklearn.model_selection import train_test_split

# %%
X = df['MonthlyIncome']
y = df['TotalWorkingYears']

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.4, random_state=101)

# %%
from sklearn.linear_model import LinearRegression

# %%
lm = LinearRegression()

# %%
lm.fit(X_train.values.reshape(-1,1),y_train)
# Out:
# LinearRegression()

# %%
print('intercept:',lm.intercept_)
print('\n')
print('slope:', lm.coef_)
# Out:
# intercept: 2.4150248735846063
#
#
# slope: [0.00131978]

# %%
predictions = lm.predict(X_test.values.reshape(-1,1))

# %%
from sklearn import metrics

# %%
print('MAE:', metrics.mean_absolute_error(y_test, predictions))
print('MSE:', metrics.mean_squared_error(y_test, predictions))
print('RMSE:', np.sqrt(metrics.mean_squared_error(y_test, predictions)))
# Out:
# MAE: 3.831441325876667
# MSE: 25.220383538156234
# RMSE: 5.021989997815232
